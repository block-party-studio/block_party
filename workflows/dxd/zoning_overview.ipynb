# %%
import text_search, ops, geotag

# %%
import numpy as np
import pandas as pd
import importlib

# %%
importlib.reload(text_search)
# Out:
# Importing en_core_web_lg...
# <module 'text_search' from '/Users/sarah/Documents/repos/block_party/analysis_tools/text_search.py'>

# %% [markdown]
# # Zoning Filter
# Filter case study dataset by list of words.

# %%
# Create an instance of the Constants class and pass the path to the YAML file
constants = ops.Constants('../../analysis_tools/config.yaml')
# Access the data in the YAML file
# case_study_terms = constants.constants['zoning_key_terms']

case_study_terms = constants.constants['character_key_terms']

# %% [markdown]
# Structure of each dataframe will be a list of words to filter by, if a transcript contains any of the words it will pass through the filter.

# %%
# read case study data
df = pd.read_pickle("../../data/zoning_case_study.pkl")

# %% [markdown]
# Create list of sentences that contain the input list of search terms.
#
# Requirement to enable the matching to occur:
# 1. All in lower case
# 2. Requires boundaries (ie. Rezoning will not match if input phrase is zoning, therefore must define independently.)

# %%
# define terms to search by
input_dict = {'Zoning': case_study_terms}
input_dict
# Out:
# {'Zoning': ['zoning', 'variance']}

# %%
# define terms to search by
input_dict = {'Character': case_study_terms}
input_dict
# Out:
# {'Character': ['landmark',
#   'preservation',
#   'preserve',
#   'character',
#   'historic']}

# %%
# test = df.head()

# %%
# split transcript if contains the key word used in dictionary

# %%
data = [ "They had a re zonings problem in the Pacific. The Pacific Zoning area was problematic. And we have lots of rezoning questions about the Grand Pacific rezoning. Unfortunately, right now, as you mentioned, our only tool to accommodate something like that and the binding is the type of structure that we recently did with grand and the grand Pacific rezoning Mike."]

# %%
test_df = pd.DataFrame(data, columns=['fullTranscript'])

# %%
test_df['fullTranscript'][0]
# Out:
# 'They had a re zonings problem in the Pacific. The Pacific Zoning area was problematic. And we have lots of rezoning questions about the Grand Pacific rezoning. Unfortunately, right now, as you mentioned, our only tool to accommodate something like that and the binding is the type of structure that we recently did with grand and the grand Pacific rezoning Mike.'

# %%
# Create an instance of the class
obj = text_search.TextParser(df=df, input_dict = input_dict)

# %%
df.loc[:, "key_sentence"] = df["fullTranscript"].apply(lambda x: obj.filterTextByRegexPtn(text_input=x))
# Out:
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historical
# Text: preserved
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: character
# Text: characteristic
# Text: preserve
# Text: historic
# Text: historically
# Text: landmark
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: preservationists
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: landmarks
# Text: preservations
# Text: historic
# Text: preservation
# Text: landmarks
# Text: historical
# Text: character
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: preserved
# Text: preserve
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmark
# Text: historic
# Text: preservation
# Text: preservation
# Text: landmarks
# Text: historical
# Text: landmark
# Text: Landmarks
# Text: historic
# Text: Preservation
# Text: Preservation
# Text: preservationist
# Text: Landmarks
# Text: historic
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: landmarks
# Text: Landmarks
# Text: historic
# Text: landmarks
# Text: preserve
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: Landmarks
# Text: Preservation
# Text: landmark
# Text: landmarks
# Text: landmark
# Text: Landmarks
# Text: landmark
# Text: historically
# Text: character
# Text: landmark
# Text: historic
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: historic
# Text: landmark
# Text: historic
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: historical
# Text: historical
# Text: landmark
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: preserved
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: landmarks
# Text: historical
# Text: landmark
# Text: landmarks
# Text: historically
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: historic
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: historic
# Text: historically
# Text: landmark
# Text: landmark
# Text: landmark
# Text: historic
# Text: landmark
# Text: historic
# Text: landmark
# Text: landmark
# Text: Landmark
# Text: historically
# Text: Historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: Preservation
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: preserved
# Text: preserve
# Text: landmarks
# Text: historic
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: character
# Text: character
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: Historically
# Text: landmarks
# Text: historic
# Text: character
# Text: Landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preserved
# Text: characterize
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preserve
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmark
# Text: Historical
# Text: Historical
# Text: Historical
# Text: Historical
# Text: landmarks
# Text: preservation
# Text: Landmarks
# Text: Preservation
# Text: Historical
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: characteristic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: Historical
# Text: landmark
# Text: landmarks
# Text: Landmarks
# Text: Landmarks
# Text: preserve
# Text: landmarks
# Text: historic
# Text: historic
# Text: Landmarks
# Text: Landmarks
# Text: landmarks
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmark
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: Preservation
# Text: preservation
# Text: preservation
# Text: historic
# Text: preservation
# Text: preservation
# Text: landmarks
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: character
# Text: landmarks
# Text: landmarks
# Text: Historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: preserve
# Text: preserve
# Text: preserve
# Text: preserve
# Text: preserved
# Text: preserved
# Text: preserve
# Text: preserve
# Text: preserved
# Text: preservation
# Text: landmark
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmark
# Text: landmark
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: Preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: Historical
# Text: historic
# Text: character
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmark
# Text: preservation
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: historic
# Text: historic
# Text: historically
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preserve
# Text: historic
# Text: historic
# Text: historically
# Text: preserve
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: characteristics
# Text: historic
# Text: landmarks
# Text: historic
# Text: characterize
# Text: characterize
# Text: historic
# Text: historically
# Text: historically
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: Landmarks
# Text: historic
# Text: Landmarks
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historical
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarking
# Text: landmark
# Text: historic
# Text: landmark
# Text: landmark
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: preservationists
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: character
# Text: preserve
# Text: character
# Text: historic
# Text: historic
# Text: historical
# Text: preserve
# Text: historical
# Text: preserve
# Text: preserve
# Text: historic
# Text: Landmark
# Text: preserve
# Text: character
# Text: historic
# Text: preserve
# Text: historic
# Text: historic
# Text: preserves
# Text: historic
# Text: character
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historical
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historical
# Text: historical
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: historical
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: character
# Text: historic
# Text: landmarks
# Text: preservation
# Text: historic
# Text: preserved
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preserved
# Text: historic
# Text: historic
# Text: character
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: Historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historical
# Text: historic
# Text: preservation
# Text: landmark
# Text: preservation
# Text: historical
# Text: historic
# Text: historic
# Text: landmark
# Text: landmarks
# Text: historical
# Text: historical
# Text: historical
# Text: historic
# Text: historic
# Text: landmark
# Text: landmark
# Text: historic
# Text: preserve
# Text: character
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: character
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: characterize
# Text: historic
# Text: historic
# Text: character
# Text: character
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: Landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: Landmarks
# Text: Preservation
# Text: landmark
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: historical
# Text: historically
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: Preservation
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: preservation
# Text: historic
# Text: historic
# Text: Landmarks
# Text: Preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmark
# Text: Preservation
# Text: landmark
# Text: Historic
# Text: landmarks
# Text: historic
# Text: Landmarks
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: historically
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: characters
# Text: historic
# Text: landmark
# Text: preservation
# Text: Landmark
# Text: landmark
# Text: landmark
# Text: character
# Text: landmarking
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmark
# Text: Preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarking
# Text: preserve
# Text: preserve
# Text: character
# Text: historical
# Text: historic
# Text: landmarks
# Text: historical
# Text: historically
# Text: landmarks
# Text: historically
# Text: landmarks
# Text: historic
# Text: preserve
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: preservation
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: landmark
# Text: landmark
# Text: landmark
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historically
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historic
# Text: preserved
# Text: historical
# Text: preserved
# Text: historical
# Text: historically
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: historic
# Text: historically
# Text: preservation
# Text: preservation
# Text: landmark
# Text: preservation
# Text: landmark
# Text: historical
# Text: historic
# Text: preserve
# Text: preservation
# Text: historic
# Text: landmark
# Text: historic
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historic
# Text: preservation
# Text: preserve
# Text: preservation
# Text: historic
# Text: Landmarks
# Text: preservation
# Text: historical
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preserve
# Text: historic
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: Historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historical
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: historic
# Text: preserve
# Text: character
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characteristically
# Text: historic
# Text: preservation
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Text: character
# Text: historic
# Text: preserved
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: landmarks
# Text: Preservation
# Text: character
# Text: historically
# Text: historically
# Text: landmarks
# Text: historic
# Text: character
# Text: landmarks
# Text: landmarks
# Text: Preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: preservation
# Text: landmark
# Text: landmark
# Text: preserve
# Text: historic
# Text: historic
# Text: historic
# Text: historical
# Text: historic
# Text: character
# Text: preserve
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: characterization
# Text: preserve
# Text: landmarked
# Text: preserve
# Text: preserve
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: landmark
# Text: historical
# Text: Landmarks
# Text: Preservation
# Text: landmarked
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: character
# Text: character
# Text: character
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: preserve
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: Landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: Preservation
# Text: Landmarks
# Text: Preservation
# Text: Landmarks
# Text: Preservation
# Text: Landmarks
# Text: Landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Text: preservation
# Text: preservation
# Text: preservation
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preserve
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: characteristics
# Text: historic
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: Preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: Landmarks
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historically
# Text: historically
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: preserve
# Text: historic
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: historic
# Text: landmarks
# Text: preservation
# Text: historic
# Text: characters
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: Preservation
# Text: historic
# Text: preservation
# Text: landmarking
# Text: historic
# Text: preservation
# Text: landmarking
# Text: preservation
# Text: historic
# Text: landmarking
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarking
# Text: landmarking
# Text: preservation
# Text: landmark
# Text: Landmarks
# Text: preserved
# Text: landmark
# Text: historical
# Text: preserve
# Text: historical
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: landmark
# Text: historic
# Text: landmarking
# Text: historic
# Text: preservation
# Text: preservation
# Text: historical
# Text: historical
# Text: historically
# Text: character
# Text: characteristics
# Text: landmarks
# Text: landmarking
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characterizes
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characterization
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserved
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characteristics
# Text: characteristic
# Text: landmarks
# Text: landmarks
# Text: Preservation
# Text: landmarks
# Text: historic
# Text: preservation
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: character
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: landmark
# Text: historic
# Text: landmark
# Text: landmark
# Text: landmark
# Text: preservation
# Text: preservation
# Text: historic
# Text: preservation
# Text: preserved
# Text: preservation
# Text: preservation
# Text: Historically
# Text: historic
# Text: landmark
# Text: landmark
# Text: landmark
# Text: Landmarks
# Text: historical
# Text: landmarks
# Text: landmark
# Text: historic
# Text: Landmark
# Text: preservation
# Text: Landmark
# Text: Preservation
# Text: landmark
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preserved
# Text: preservation
# Text: preservation
# Text: preserve
# Text: preserve
# Text: preservation
# Text: preserve
# Text: preserve
# Text: preservation
# Text: historic
# Text: preservation
# Text: preserved
# Text: historical
# Text: preservation
# Text: preserve
# Text: preserved
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: preserve
# Text: landmark
# Text: historic
# Text: landmark
# Text: preservation
# Text: landmark
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserved
# Text: historic
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: Landmarks
# Text: preservation
# Text: Landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: landmarks
# Text: landmark
# Text: historic
# Text: characteristic
# Text: landmark
# Text: historical
# Text: historical
# Text: landmarks
# Text: landmark
# Text: historic
# Text: landmarks
# Text: historic
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: historic
# Text: landmark
# Text: landmarks
# Text: preserve
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Text: preservations
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: landmark
# Text: Landmarks
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: historical
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: character
# Text: character
# Text: Historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmark
# Text: preservation
# Text: historic
# Text: landmarking
# Text: historic
# Text: historic
# Text: preservation
# Text: character
# Text: historic
# Text: character
# Text: preserve
# Text: character
# Text: preserve
# Text: historic
# Text: landmark
# Text: preserved
# Text: preserve
# Text: landmarked
# Text: landmarks
# Text: landmarks
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: historic
# Text: Historic
# Text: Preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preserve
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: historical
# Text: historic
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: Historical
# Text: historical
# Text: preservationist
# Text: landmark
# Text: historic
# Text: historic
# Text: preservation
# Text: historical
# Text: historical
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characteristics
# Text: Preservation
# Text: Landmarks
# Text: landmark
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: Landmarks
# Text: historic
# Text: Landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characterizing
# Text: characters
# Text: characterize
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: characters
# Text: historically
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historically
# Text: preserve
# Text: characters
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: preserve
# Text: preserve
# Text: preserve
# Text: preserve
# Text: landmarked
# Text: landmarks
# Text: character
# Text: character
# Text: character
# Text: character
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Historically
# Text: character
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: preserve
# Text: preserve
# Text: preservation
# Text: preservation
# Text: preservation
# Text: Preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservationist
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preserve
# Text: preservation
# Text: preserved
# Text: landmark
# Text: historic
# Text: landmark
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: Landmarks
# Text: historical
# Text: historic
# Text: historic
# Text: preserved
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: landmark
# Text: preservation
# Text: preservation
# Text: historic
# Text: landmarks
# Text: Preservation
# Text: preservation
# Text: preservation
# Text: landmark
# Text: landmark
# Text: Landmarks
# Text: landmark
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: preservation
# Text: landmarking
# Text: landmark
# Text: landmark
# Text: landmark
# Text: landmarking
# Text: preservation
# Text: preserve
# Text: historical
# Text: landmark
# Text: landmarked
# Text: landmarking
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmark
# Text: historic
# Text: Landmark
# Text: historic
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: historical
# Text: historical
# Text: preserve
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: Preservation
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: character
# Text: historic
# Text: landmark
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmark
# Text: character
# Text: characteristics
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: Historic
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preserve
# Text: historic
# Text: character
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historic
# Text: historic
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: character
# Text: preserve
# Text: landmarked
# Text: character
# Text: landmarks
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: historical
# Text: historical
# Text: Landmark
# Text: Landmark
# Text: Landmark
# Text: Landmark
# Text: landmark
# Text: Landmark
# Text: Landmark
# Text: Landmark
# Text: landmark
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historic
# Text: preserve
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characteristic
# Text: landmark
# Text: preservation
# Text: historic
# Text: landmark
# Text: landmark
# Text: preservation
# Text: landmarking
# Text: landmark
# Text: landmarking
# Text: landmarked
# Text: landmarks
# Text: landmarking
# Text: landmarked
# Text: historical
# Text: landmarked
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: Landmarks
# Text: Preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarking
# Text: landmark
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: landmarks
# Text: preserved
# Text: landmark
# Text: landmark
# Text: landmark
# Text: Landmarks
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: historic
# Text: historic
# Text: landmark
# Text: Landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: historic
# Text: preservation
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: character
# Text: historic
# Text: historic
# Text: landmark
# Text: historic
# Text: landmark
# Text: historic
# Text: landmarks
# Text: historic
# Text: landmark
# Text: historic
# Text: landmark
# Text: historic
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: landmarks
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characteristics
# Text: historical
# Text: historically
# Text: historically
# Text: historical
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarked
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: historically
# Text: characteristic
# Text: landmarks
# Text: Landmarks
# Text: Preservation
# Text: historical
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: historic
# Text: preserve
# Text: preserve
# Text: preserved
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmark
# Text: Preservation
# Text: preserve
# Text: landmarks
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: landmark
# Text: historic
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: preserve
# Text: Historically
# Text: characteristics
# Text: landmark
# Text: Landmark
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: historically
# Text: historically
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: preserved
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: landmark
# Text: preservation
# Text: landmark
# Text: preservation
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: landmarks
# Text: historic
# Text: landmark
# Text: landmarks
# Text: Historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Text: Landmarks
# Text: Landmarks
# Text: Landmarks
# Text: Preservation
# Text: landmark
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: landmark
# Text: preservation
# Text: preservation
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: preservation
# Text: character
# Text: character
# Text: character
# Text: character
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: preserve
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: Landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: historically
# Text: landmark
# Text: historically
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preservation
# Text: characters
# Text: characters
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: Landmarks
# Text: Preservation
# Text: landmark
# Text: historical
# Text: historic
# Text: historical
# Text: Landmarks
# Text: Preservation
# Text: historical
# Text: historical
# Text: preservation
# Text: historical
# Text: landmarks
# Text: Preservation
# Text: preserve
# Text: preservation
# Text: preservation
# Text: preservation
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: landmarks
# Text: character
# Text: historically
# Text: historic
# Text: historic
# Text: historic
# Text: preserved
# Text: preserve
# Text: preserves
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: landmarks
# Text: landmark
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmark
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: Preservation
# Text: historical
# Text: historical
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: historically
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: Preservation
# Text: historic
# Text: landmark
# Text: characterized
# Text: character
# Text: historically
# Text: historically
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: Landmarks
# Text: Preservation
# Text: landmarks
# Text: landmark
# Text: landmark
# Text: preservation
# Text: Landmarks
# Text: Preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: preserved
# Text: preserve
# Text: historic
# Text: historic
# Text: preserve
# Text: landmark
# Text: preserve
# Text: preservation
# Text: preserved
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: preserved
# Text: historic
# Text: preservationists
# Text: landmark
# Text: historical
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: preservation
# Text: historic
# Text: preservation
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: Preservation
# Text: Landmarks
# Text: landmarks
# Text: historic
# Text: landmarking
# Text: preserve
# Text: historic
# Text: landmarking
# Text: Landmark
# Text: Preservation
# Text: Historic
# Text: Landmarks
# Text: historic
# Text: preservation
# Text: historic
# Text: preservationists
# Text: preservation
# Text: landmarks
# Text: Historic
# Text: historic
# Text: landmark
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: landmark
# Text: historic
# Text: landmark
# Text: historic
# Text: preserved
# Text: historic
# Text: historic
# Text: historic
# Text: landmarked
# Text: Landmarks
# Text: Preservation
# Text: Landmarks
# Text: historic
# Text: historical
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: landmarking
# Text: historic
# Text: preservation
# Text: historically
# Text: historically
# Text: historic
# Text: Landmarks
# Text: Preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: Landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: historical
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Text: historically
# Text: historically
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characterized
# Text: preserve
# Text: preserve
# Text: preserve
# Text: historic
# Text: character
# Text: character
# Text: characteristics
# Text: Landmarks
# Text: Landmarks
# Text: historic
# Text: character
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: character
# Text: historic
# Text: character
# Text: character
# Text: character
# ...
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: Landmark
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: preservation
# Text: preservation
# Text: character
# Text: landmarks
# Text: Landmark
# Text: landmark
# Text: landmarks
# Text: characteristics
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: mischaracterizations
# Text: historic
# Text: preservation
# Text: landmarking
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: preserve
# Text: preservation
# Text: preserve
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: characters
# Text: characterizing
# Text: Landmark
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: Historic
# Text: Historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarked
# Text: landmarked
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmark
# Text: historical
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: Landmark
# Text: Landmark
# Text: landmarks
# Text: landmarks
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Text: historical
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preserved
# Text: preserved
# Text: preserve
# Text: preserve
# Text: preserve
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preserve
# Text: preservation
# Text: preserves
# Text: preservation
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: characterization
# Text: character
# Text: characterization
# Text: preserved
# Text: character
# Text: historically
# Text: historic
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: preservationist
# Text: historic
# Text: landmarks
# Text: preservation
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: character
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: historic
# Text: landmark
# Text: preservation
# Text: preserve
# Text: historic
# Text: characterized
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: character
# Text: character
# Text: historic
# Text: characteristics
# Text: historic
# Text: historic
# Text: Landmark
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: Historic
# Text: preservation
# Text: historic
# Text: landmark
# Text: landmarks
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historic
# Text: landmarks
# Text: character
# Text: preservation
# Text: preservation
# Text: Landmark
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: Landmark
# Text: landmarks
# Text: preservation
# Text: historical
# Text: historic
# Text: landmarks
# Text: landmark
# Text: Landmark
# Text: landmarks
# Text: landmark
# Text: historical
# Text: landmark
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: preservation
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: characteristics
# Text: landmarks
# Text: historic
# Text: landmark
# Text: landmarked
# Text: landmarks
# Text: preservation
# Text: landmark
# Text: Landmark
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: preservation
# Text: historic
# Text: Historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserved
# Text: historic
# Text: landmarked
# Text: landmarking
# Text: historic
# Text: preservationists
# Text: historic
# Text: Historic
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: historical
# Text: characteristics
# Text: preservation
# Text: preservation
# Text: characterized
# Text: characterized
# Text: historically
# Text: preserve
# Text: character
# Text: character
# Text: characterized
# Text: characterized
# Text: character
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: character
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: landmark
# Text: preserve
# Text: preserve
# Text: characters
# Text: historic
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmark
# Text: preservation
# Text: preserve
# Text: preserve
# Text: landmarked
# Text: Landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preserve
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmarks
# Text: historic
# Text: historically
# Text: historically
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: Landmark
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: characters
# Text: character
# Text: preservation
# Text: historic
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: preserved
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: historic
# Text: historical
# Text: preservation
# Text: historic
# Text: historic
# Text: preservation
# Text: preserve
# Text: preservation
# Text: landmark
# Text: historical
# Text: preservation
# Text: historic
# Text: preservation
# Text: preserved
# Text: preservationists
# Text: historic
# Text: historic
# Text: preservation
# Text: preservationists
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: preserve
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: landmark
# Text: preservation
# Text: historic
# Text: Historic
# Text: historic
# Text: landmark
# Text: preservation
# Text: historic
# Text: Landmark
# Text: preservation
# Text: historic
# Text: Landmark
# Text: historic
# Text: landmarks
# Text: Landmark
# Text: landmark
# Text: preservation
# Text: landmarks
# Text: historically
# Text: historic
# Text: Landmark
# Text: landmark
# Text: Landmark
# Text: landmark
# Text: Landmark
# Text: Landmark
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: landmarks
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: historical
# Text: characteristics
# Text: preservation
# Text: preservation
# Text: characterized
# Text: characterized
# Text: historically
# Text: preserve
# Text: character
# Text: character
# Text: characterized
# Text: characterized
# Text: character
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: mischaracterizing
# Text: mischaracterized
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmark
# Text: landmarks
# Text: preservation
# Text: landmark
# Text: Landmark
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Text: character
# Text: historic
# Text: historic
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: Landmark
# Text: Landmark
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: landmarks
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historically
# Text: historically
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: preservation
# Text: preservation
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historically
# Text: historically
# Text: historical
# Text: characteristically
# Text: historically
# Text: historic
# Text: preserve
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: Landmark
# Text: landmarks
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: character
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historical
# Text: historic
# Text: characteristic
# Text: characteristics
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: preservation
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: historic
# Text: preservation
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: preserved
# Text: historically
# Text: preservation
# Text: historically
# Text: character
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historic
# Text: historic
# Text: preservation
# Text: historic
# Text: preserved
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: preservation
# Text: preservation
# Text: preservation
# Text: historic
# Text: preservation
# Text: historic
# Text: preservation
# Text: preservation
# Text: historic
# Text: historic
# Text: preserve
# Text: historic
# Text: preservation
# Text: historic
# Text: historic
# Text: historic
# Text: preservation
# Text: preservation
# Text: preserved
# Text: preservation
# Text: historic
# Text: preservation
# Text: preservation
# Text: historic
# Text: historic
# Text: Landmark
# Text: landmarks
# Text: preservationists
# Text: preservationist
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: landmarks
# Text: Landmark
# Text: preserve
# Text: landmark
# Text: preservation
# Text: landmarks
# Text: preservation
# Text: preservation
# Text: historic
# Text: historical
# Text: character
# Text: historic
# Text: landmarks
# Text: preservation
# Text: historic
# Text: Landmark
# Text: landmark
# Text: preservation
# Text: landmark
# Text: Landmark
# Text: preservation
# Text: historic
# Text: historic
# Text: landmarks
# Text: historic
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: historic
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historically
# Generating Matcher object for [{'TEXT': {'REGEX': '(?i)(landmark|preservation|preserve|character|historic)'}}]
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historic
# Text: historically
# Text: historically
# Text: historical
# Text: characteristically
# Text: historical
# Text: historic
# Text: preserve
# Text: landmarks
# Text: historic
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: landmarks
# Text: Landmark
# Text: landmarks
# Text: historic

# %%
# add this to take unique set
df.loc[:, 'key_sentence'] = df['key_sentence'].apply(lambda x: set([i for i in x]))

# %% [markdown]
# Following LOC extraction was not very accurate, should refer to geotag notebook.

# %%
df.loc[:, "LOC_list"] = df["key_sentence"].apply(lambda x: text_search.extract_ents(" ".join(x), NERTag="LOC"))

# %%
# perhaps consider consolidating into unique list, although it could be beneficial to know frequency
set(test_df.LOC_list[0])
# Out:
# {'Grand Pacific', 'Pacific', 'Pacific Zoning'}

# %% [markdown]
# For all the sentences that are about zoning, let's extract the LOCs

# %%
df.head(1)
# Out:
#                         _id     videoURL              normalizedName  \
# 0  5fe7e243539a4d487dc18b65  tv-N4M_zCT4  Brooklyn Community Board 8
#
#            publishDate               title  \
# 0  2020-11-06T00:00:00  Land Use Committee
#
#                                          meetingType  \
# 0  [[0.4097696840763092, Landmarks], [0.376285165...
#
#                                       fullTranscript lengthSeconds  \
# 0  Good at it today, let's see okay, so there see...       2:45:00
#
#                              wordCountFullTranscript  \
# 0  {'building': 89, 'landmarks': 35, 'units': 31,...
#
#                                     wordCountSummary  \
# 0  {'building': 17, 'owners': 10, 'landmarks': 9,...
#
#                                         key_sentence
# 0  {They all offer grants New York, Landmarks, Co...

# %%
df.to_pickle("../../data/character_caseStudy_sentences.pkl")

# %%
# count number of LOC for a given slice

# %%
import itertools
from collections import Counter

# %%
df.to_pickle("../../data/caseStudy_sentences.pkl")

# %%
df = pd.read_pickle("../../data/caseStudy_sentences.pkl")

# %%
df = pd.read_pickle("../../data/character_caseStudy_sentences.pkl")

# %%
# unique row for each sentence.
df = df.explode(['key_sentence'])

# %%
df.shape
# Out:
# (19675, 11)

# %%
# filter out any CB that does not have any data 
df.dropna(axis='rows', subset='key_sentence', inplace=True)

# %%
df.shape
# Out:
# (19337, 11)

# %% [markdown]
# More robust geotagging approach:

# %% [markdown]
# Performance doesn't appear to change based on context...likely more BoW than expected.

# %%
# apply to dataframe
df.loc[:, "loc_extract_list"] = df["key_sentence"].apply(lambda x: geotag.get_location_from_text(x))

# %%
df.head()
# Out:
#                         _id     videoURL              normalizedName          publishDate               title                                        meetingType                                     fullTranscript lengthSeconds                            wordCountFullTranscript                                   wordCountSummary                                       key_sentence                    loc_extract_list
# 0  5fe7e243539a4d487dc18b65  tv-N4M_zCT4  Brooklyn Community Board 8  2020-11-06T00:00:00  Land Use Committee  [[0.4097696840763092, Landmarks], [0.376285165...  Good at it today, let's see okay, so there see...       2:45:00  {'building': 89, 'landmarks': 35, 'units': 31,...  {'building': 17, 'owners': 10, 'landmarks': 9,...  They all offer grants New York, Landmarks, Con...  [New York, Landmarks, Conservancy]
# 0  5fe7e243539a4d487dc18b65  tv-N4M_zCT4  Brooklyn Community Board 8  2020-11-06T00:00:00  Land Use Committee  [[0.4097696840763092, Landmarks], [0.376285165...  Good at it today, let's see okay, so there see...       2:45:00  {'building': 89, 'landmarks': 35, 'units': 31,...  {'building': 17, 'owners': 10, 'landmarks': 9,...  Miss young I want to make sure that the owners...                              [Miss]
# 0  5fe7e243539a4d487dc18b65  tv-N4M_zCT4  Brooklyn Community Board 8  2020-11-06T00:00:00  Land Use Committee  [[0.4097696840763092, Landmarks], [0.376285165...  Good at it today, let's see okay, so there see...       2:45:00  {'building': 89, 'landmarks': 35, 'units': 31,...  {'building': 17, 'owners': 10, 'landmarks': 9,...  I'm surprised and appalled that department of ...                                 NaN
# 0  5fe7e243539a4d487dc18b65  tv-N4M_zCT4  Brooklyn Community Board 8  2020-11-06T00:00:00  Land Use Committee  [[0.4097696840763092, Landmarks], [0.376285165...  Good at it today, let's see okay, so there see...       2:45:00  {'building': 89, 'landmarks': 35, 'units': 31,...  {'building': 17, 'owners': 10, 'landmarks': 9,...  If I may, miss Tyus I have great respect for t...                                 NaN
# 0  5fe7e243539a4d487dc18b65  tv-N4M_zCT4  Brooklyn Community Board 8  2020-11-06T00:00:00  Land Use Committee  [[0.4097696840763092, Landmarks], [0.376285165...  Good at it today, let's see okay, so there see...       2:45:00  {'building': 89, 'landmarks': 35, 'units': 31,...  {'building': 17, 'owners': 10, 'landmarks': 9,...  The yield 1, so I can supersede the applicant ...                                 NaN

# %%
# add filter when the sentence has 'character' as these will likely be more zesty

df.loc[df['key_sentence'].str.contains('character'), 'character_flag'] = True

# %%
# likely where should start search
df['character_flag'].sum()/len(df)
# Out:
# 0.1282515385013187

# %%
df.drop(columns=['fullTranscript']).to_csv("../../data/character_caseStudy_sentences_LOC.csv", index=False)

# %% [markdown]
# 'Bronx Community Board 6' and 'Queens Community Board 8' are inactive on Youtube so it's okay we don't have anything to surface.
#
# Will drop the following:
#
# {'Bronx Community Board 6',
#  'Brooklyn Borough President',
#  'Manhattan Borough President',
#  'Queens Borough President',
#  'Queens Community Board 8',
#  'Staten Island Borough President'}

# %%
df[(df['key_sentence'].str.contains('Soho')) ]['key_sentence'].value_counts().head(20)
# Out:
# I think it burdens the few remaining jail wqa tenants who have stayed throughout this long history without recognizing the benefits that others have obtained by converting their spaces in Soho, Noho I think the arts fund mechanism needs serious work and I worry that we are in fact undermining the integrity of the historic districts.\n                                                                                                                                                                                                                                                                                                              2
# The Soho Noho neighborhood plan stands for the idea that, with focused planning and robust public dialogue, all neighborhoods across the city can play a part in the solutions to the planning challenges that we as New Yorkers face by bringing flexible and modern zoning to these historic mixed-use neighborhoods.\n                                                                                                                                                                                                                                                                                                                                     2
# These are our landmarks that are to be preserved for public enjoyment for hundreds of years to come, and the notion that the mayor is doing this in Soho in the seaports in the meatpacking district, where I am at this moment is absolutely vulgar and as Cpc testified, this wasn't for us.                                                                                                                                                                                                                                                                                                                                                                1
# Another really important reminder is that 80 of the rezoning area is when the within a historic district and our proposal does nothing to undermine the landmark's law, of course, and they, the landmarks commission, enjoys their and exercises their the full extent of their landmarks laws related to Soho, no, which includes, of course protections to the historic district and individual buildings, and I also want to note that in many ways you know this is a really a tremendous support to the proposal as a tremendous support to recognize the special building character of Soho Noho and that for the first time they're.\n                1
# We see that Soho Noho is a very desirable place to do business so honoho today are home to a diverse set of non-industrial sectors and a mix of uses, and our proposal really again is to strengthen the mixed-use character, which makes these areas so special, dynamic, attractive and resilient, and we believe appropriate FAR to reflect this reality of Soho Noho and its role to the city is not just an important signal for businesses who might want to locate there, but to the many thousands of businesses that are already there to acknowledge that they are there, their home is there and, if it, and that perhaps they may even grow.\n    1
# This was triggered not by anything in our district but by 250 water street, which is in community district, one which is a huge tall building in the middle of the south street Seaport historic district and preservationists throughout the city are outraged and asking for you know a little bit of pressure on the landmarks commission about that there's a little bit about the Soho Noho district, also which impinges on the historic district that rezoning proposal.\n                                                                                                                                                                             1
# Speaking for the New York landmarks conservancy, the conservancy was a member of the Soho Noho advisory group.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# The financial pressures on residents in JLWQA units may be exacerbated by this if they are in buildings with mixed designations, the entire plan ignores historic districts, their value to the city and Soho as a national, historic, landmark district, but this mayor weakened, landmark preservation rules and with no concern for the value of history that other major cities work diligently to protect.\n                                                                                                                                                                                                                                             1
# But by increasing the far you are allowing developers to build over these buildings, which will completely change the landscape of Soho and the old landmarks preservation would never have allowed it that and they never did, and they would.                                                                                                                                                                                                                                                                                                                                                                                                               1
# and I tell you that I was at the city planning commission hearing yesterday about the Seaport, where I live, where I opposed the outside outsize and inappropriate development that is being requested by Howard hughes corporation I also oppose the Soho Noho rezoning as a preservationist and as a person interested in historic preservation and the long-term good that this area brings to New York in terms of the richness of life, the hearkening back to history, the cast iron buildings, the small galleries and publishers and all the art and restaurants that go on in Soho and Noho.\n                                                       1
# Consequently, the Soho Noho upzoning was set a dangerous precedent for the destruction of historic districts all over the city.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Then five people and support and go back and forth in that manner until all of the remaining 88 speakers and rajing have been heard from, and so our next speaker is Louise Carroll good morning, I'm Louise Carroll, I'm the commissioner of the New York City department of housing, preservation and development, and I'm happy to be here today to share my perspective on the importance of the Soho.\n                                                                                                                                                                                                                                                  1
# The advisory group agreed that the historic character of Soho and Noho should be preserved, but the proposal allows nearly doubling the size of new buildings in historic districts, even as it acknowledges that this will create little affordable housing within the district boundaries.\n                                                                                                                                                                                                                                                                                                                                                                1
# Luxury condo, construction and hotels included in Soho and Noho are some of the city's most popular historic districts.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Our next speaker is Richard Moses to be followed by jennifer carlson good afternoon commissioners and madam chair, I'm richard Moses, president of the Lower East Side preservation initiative, also known as Lesbi strongly opposes the mayor's plan to up Zone, Soho and Noho, which includes parts of Chinatown and the east village.\n                                                                                                                                                                                                                                                                                                                    1
# Neighborhood plan includes a dramatic increase in pharah that would impact a 56 block, 146 acre project area, 80 of which overlaps the boundaries of six historic districts, including the Soho cast iron historic district.\n                                                                                                                                                                                                                                                                                                                                                                                                                                1
# I love, Soho, Noho, Chinatown, don't destroy this historic area.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# We can minimize community preference to make sure that it is those who are at risk who are brought to Soho and to put my preservationist path back on.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# It's very clear that increasing the far particularly on the core buildings in Soho, which you are doing and the landmark are the cast iron buildings, which are a unique form of architecture that are only exist now in Soho, Noho Tribeca, except for a few buildings in chicago and a few in paris.\n                                                                                                                                                                                                                                                                                                                                                      1
# Stop it just stop it CPC vote no on the Soho Noho Chinatown resulting and pass community plans that really preserve the creation of the low income housing like the Chinatown working group plan.\n                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Name: key_sentence, dtype: int64

# %%
# Duplicates occur when the sentence has key term mentioned more than once, will count each utterance.

test = "You know there were really kind of two separate entities in terms of the rezonings that have come to the community board over the last five years, or so you have the Pacific Street, rezonings, 10:50, Grand and Pacific, and then they're the Atlantic Avenue rezonings and the Atlantic Avenue rezonings.\n"

# %%
df[df['key_sentence'] == test]
# Out:
#                            _id     videoURL              normalizedName  \
# 1988  638de23f2e36caac5847bf40  NDQ9S3ohVBE  Brooklyn Community Board 8
# 1988  638de23f2e36caac5847bf40  NDQ9S3ohVBE  Brooklyn Community Board 8
# 1988  638de23f2e36caac5847bf40  NDQ9S3ohVBE  Brooklyn Community Board 8
# 1988  638de23f2e36caac5847bf40  NDQ9S3ohVBE  Brooklyn Community Board 8
#
#               publishDate     title  \
# 1988  2022-12-02T00:00:00  Land Use
# 1988  2022-12-02T00:00:00  Land Use
# 1988  2022-12-02T00:00:00  Land Use
# 1988  2022-12-02T00:00:00  Land Use
#
#                                             meetingType  \
# 1988  [[0.3265550434589386, Zoning], [0.251054227352...
# 1988  [[0.3265550434589386, Zoning], [0.251054227352...
# 1988  [[0.3265550434589386, Zoning], [0.251054227352...
# 1988  [[0.3265550434589386, Zoning], [0.251054227352...
#
#                                          fullTranscript lengthSeconds  \
# 1988  Foreign Michelle good evening, everyone I just...       2:58:15
# 1988  Foreign Michelle good evening, everyone I just...       2:58:15
# 1988  Foreign Michelle good evening, everyone I just...       2:58:15
# 1988  Foreign Michelle good evening, everyone I just...       2:58:15
#
#                                 wordCountFullTranscript  \
# 1988  {'framework': 37, 'housing': 31, 'rezoning': 2...
# 1988  {'framework': 37, 'housing': 31, 'rezoning': 2...
# 1988  {'framework': 37, 'housing': 31, 'rezoning': 2...
# 1988  {'framework': 37, 'housing': 31, 'rezoning': 2...
#
#                                        wordCountSummary  \
# 1988  {'density': 11, 'uses': 11, 'framework': 11, '...
# 1988  {'density': 11, 'uses': 11, 'framework': 11, '...
# 1988  {'density': 11, 'uses': 11, 'framework': 11, '...
# 1988  {'density': 11, 'uses': 11, 'framework': 11, '...
#
#                                            key_sentence  \
# 1988  You know there were really kind of two separat...
# 1988  You know there were really kind of two separat...
# 1988  You know there were really kind of two separat...
# 1988  You know there were really kind of two separat...
#
#                                                LOC_list
# 1988  [the M1 Zone, the M1 Zone, Community District ...
# 1988  [the M1 Zone, the M1 Zone, Community District ...
# 1988  [the M1 Zone, the M1 Zone, Community District ...
# 1988  [the M1 Zone, the M1 Zone, Community District ...

# %%
df[(df['key_sentence'].str.contains('Pacific')) & (df['key_sentence'].str.contains('rezoning')) ]['key_sentence'].value_counts()
# Out:
# You know there were really kind of two separate entities in terms of the rezonings that have come to the community board over the last five years, or so you have the Pacific Street, rezonings, 10:50, Grand and Pacific, and then they're the Atlantic Avenue rezonings and the Atlantic Avenue rezonings.\n                                                                                                                                                                                                                                                                 4
# The first is the rezoning from the current m11 to along Atlantic avenue, a c63a zoning district and we'll look at the boundaries of those in a moment and along Pacific street, because this is partially a through lot, an R7A c24 district, which reflects prior rezonings that have been approved by the commission.\n                                                                                                                                                                                                                                                      3
# But if, as the applicant of Mr Peconia stated that this rezoning in this development is in line with what the community has asked for in the M crowd, rezoning plus more I don't really see the harm in entertaining this, especially if you know, if we're going to get exactly what they're asking for maybe a little bit less in what I don't exactly know the timeline for the M Crown rezoning, but several years further down the line, you know I'd rather see the site develops sooner more housing and you know, instead of an empty lot on Pacific Street, so        3
# The idea is that you have to include any rezoning or any as of right development in an area-wide rezoning that has not otherwise been built yet, and you have to use what are called projected development sites that are defined and there's only one in this case and it's the 962 Pacific site that would be included in the analysis and I want to talk about how that's included-and you know to assure this board that somehow, by doing a private rezoning, it's circumventing getting considered in a neighborhood or Eis environmental impact statement process.\n    3
# This is the area that we've been talking about here with these three different options along Atlantic avenue lots one part of lot, one nine and ten personally I would favor rezoning the lots on Pacific street to align with the neighboring zoning districts.\n                                                                                                                                                                                                                                                                                                             2
# You can see from this slide that the entire eastern and western sections of our block, including a piece of 962 Pacific Street, have been rezoned R7A, unfortunately, of the three rezonings that have resulted in R7A zoning, none has committed to M crowd uses.\n                                                                                                                                                                                                                                                                                                           2
# What would be specified in zoning was the grand Pacific rezoning, which is a lot on the corner of grand avenue and Pacific street, and although the project is I guess just breaking ground so far the developer has performed according to the agreement, but our agreements do provide for remedies for non-performance.\n                                                                                                                                                                                                                                                   2
# This turned out, maybe not to be the case demonstrated by the grand Pacific rezoning, but ultimately it did not wasn't persuasive enough to DCP for them to move forward with a neighborhood rezoning.                                                                                                                                                                                                                                                                                                                                                                         2
# Rezoning, you can see the r7a sitting to the west of the site to the east of the site are the 10 and 1050 Pacific Street rezonings, which again rezoned to an r7a equivalent.\n                                                                                                                                                                                                                                                                                                                                                                                                2
# The next rezoning that was approved by the community board was the grand and Pacific avenue rezoning the Pacific street, resulting which was which allowed for an r7d.\n                                                                                                                                                                                                                                                                                                                                                                                                       2
# Here there was the Pacific and grand rezoning which you can see in the boxed areas on Pacific and grand which allowed for R7D zoning along grand street.                                                                                                                                                                                                                                                                                                                                                                                                                       2
# How long we had been in line at City Planning dating back to 2019, that there had been other applicants who had been seen, heard and decided upon since the time of our rezoning application being submitted, and importantly, that this was one of 25 Lots on the south side of Pacific, between Grand and east, of Classen and of those 25 Lots 24 of those locks are zoned with R7A or r7a equivalent zoning.\n                                                                                                                                                             2
# You have unique original senses and then you would have to add on top Grand and Pacific rezoning projected development site, one that is near completion.\n1010 Pacific rezoning projected development site, one that is near completion on top of 2020 census, as well as any additional Development coming online.\n                                                                                                                                                                                                                                                         2
# As of yet unconstructed Development, coming from the various private rezonings Grand Pacific rezoning projected development site, two 1050 Pacific projected development sites, 1034 Atlantic projected to own sites, 809 Atlantic, 849,840, Atlantic, 870 to 80 Atlantic, 1045 Atlantic, as well as any identified DOB pipeline projects that are listed on their website, as well as ambient growth track from the Census have to establish What's called the few future, no action scenario and then from there.\n                                                          2
# We don't want to have it be lost in the course of this presentation that the rezoning, also that we're proposing also calls for rezoning a portion of Pacific street from M1 to r6b.\n                                                                                                                                                                                                                                                                                                                                                                                         2
# You'll also see that there are other rezonings in the area which have recently been approved within the last three four and even five years there were rezonings along Pacific street, specifically at 10 and 10:50, which allowed for R7A residential density, which is sought along Pacific.\n                                                                                                                                                                                                                                                                               2
# So by way of a brief introduction again, this is with regards to a rezoning application on Pacific Street between Grand and Classen Avenues.\n                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# and I know that the they specifically Grand and Pacific, which was the only RS rezoning which had a portion that was in R7A that agreement was entirely negotiated and was codified by the community board.\n                                                                                                                                                                                                                                                                                                                                                                  1
# That was the case with the Grand Pacific rezoning.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# and I have come in with developers and I think the difference you know I have a sense of history as far as what these rezonings on Pacific have been like, and for the r7a portions of these properties.\n                                                                                                                                                                                                                                                                                                                                                                     1
# It was rezoned as part of the Grand Pacific rezoning and it and it's, but it wasn't.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# That generally means they have to show they're rezoning more than the lot they control wow, and so basically, what DCP made Mr Pariente do is go across the street and do environmentals on a couple Lots on Grand Avenue on the other side of Pacific and include them in his application.\n                                                                                                                                                                                                                                                                                  1
# When we talk about like rezoning and building places, we need I think reframe sit back and actually look what is needed because M Crown Pacific Street, Dean, Street, Grand, Classen Atlantic Avenue have already like prospered, and these apartments are unaccessible to the people who we actually want to serve in our neighborhood.\n                                                                                                                                                                                                                                     1
# Thank you, mr viconi I wanted to address a couple of the comments that were made about Cbas and 840 Atlantic the so it's possible, not everybody on the call knows what we're talking about in the case of the grand Pacific rezoning in the case.\n                                                                                                                                                                                                                                                                                                                           1
# and I'm currently in involved on a rezoning on Pacific street.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# So, in addition to understanding the history of rezonings in community board 8, particularly the R7A districts, approved along Pacific in 1010 and 1050, as well as the r7d in grand Pacific.\n                                                                                                                                                                                                                                                                                                                                                                                1
# Is that true you're only looking to rezone the one lot that you control and there won't be any other lots that will come along with it, correct and in actuality, a small portion of the western side of the slot is actually already zoned R7A from the Grand and Pacific rezoning.\n                                                                                                                                                                                                                                                                                         1
# Of course, to the diagonal to the right is the other rezoning that I just spoke about Pacific, which created the CBA that I'm very impressed with up, which is you know better than I?                                                                                                                                                                                                                                                                                                                                                                                         1
# In the surrounding area, there have been a number of recent private applications, many of which are familiar with these include 1010 and 1050 Pacific street directly to the south and east, the grand avenue and Pacific street project to the west and, most recently, the 1045 Atlantic avenue project to the north and east, which involved a similar rezoning request for a C63A district, which was recently approved by the City Council.\n                                                                                                                             1
# The last rezoning that was approved by the community board of Pacific and grand was I think it was a really beneficial process where we discussed it with the community board, and we came up with a solution to a lot of to a lot of issues that were raised.\n                                                                                                                                                                                                                                                                                                               1
# So, as Ms Tyus pointed out with the City council's approval of the grand Pacific rezoning, the agreements that the community board reached with the developer, Emp capital became effective and the restricted declaration was registered with the governor finance and, as you saw that's now available on acres, we also expect there will be a memo of agreement that plays out in summary, on the existence of the community benefit.                                                                                                                                      1
# I did want to say I, don't know if this is what Mr crashes was getting at, but there are other lots that are included in the grand Pacific rezoning and, at one point I think.                                                                                                                                                                                                                                                                                                                                                                                                 1
# We also discovered that the developers who had done the rezoning for a 1010 Pacific street and had made similar commitments, but had done so only through a letter of intent with the City council member, had sold their lot and those commitments were no longer enforceable.                                                                                                                                                                                                                                                                                                1
# We discussed the community benefits agreement for the Grand Pacific rezoning, which is part of the inground project, and we discussed a handicap ramp for 1370 Dean Street.                                                                                                                                                                                                                                                                                                                                                                                                    1
# Of course, to the diagonal to the right is the other rezoning that I just spoke about Pacific, which created the CBA that I'm very impressed with, which is you know better than I do which create the mx district, which is what we're modeling ourselves after, because we're watching what you're doing and we're hoping you'll?\nLet us do the same thing.\n                                                                                                                                                                                                               1
# Unfortunately, right now, as you mentioned, our only tool to accommodate something like that and the binding is the type of structure that we recently did with grand and the grand Pacific rezoning Mike.\n                                                                                                                                                                                                                                                                                                                                                                   1
# The first comment regards trying to get other lots into this rezoning, I think doing that presents challenges for the community board in this context, unless all of the owners are interested in making the same kinds of commitments for restricted use, we had a little bit of an experience with that on grand Pacific, where we tried to bring other owners and it was difficult and it ultimately didn't work out                                                                                                                                                        1
# so when we consider this in the framework of let's say what we did with the grand Pacific rezoning, which was also an M crown there.                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Unfortunately, right now, as you mentioned, our only tool to accommodate something like that and the binding is the type of structure that we recently did with grand and the grand Pacific rezoning Mike.                                                                                                                                                                                                                                                                                                                                                                     1
# This is similar to what was done in the case of the grand Pacific rezoning.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# In the case of grand Pacific rezoning in 2019, it will take the form of a restrictive declaration that outlines all of the public commitments and that will be filed with the deed in the chain of title and will be available to the public.\n                                                                                                                                                                                                                                                                                                                                1
# This is exactly the same structure that we implemented with the grand Pacific rezoning and so I think we have accomplished the mission of securing a binding commitment for these obligations so with that                                                                                                                                                                                                                                                                                                                                                                     1
# This is a rezoning of a parcel of approximately 24,000 square feet, of which roughly eighteen thousand square feet lies along Pacific and a six thousand square foot portion along Atlantic.                                                                                                                                                                                                                                                                                                                                                                                   1
# The Pacific street building I would note, is nine stories that would be rezoned to R seven, a C two four, that rezoning is one that has already been approved by this community board on that block previously on 1010 Pacific, the community board approved r7a bulk, as well as for 10.50, also on Pacific street, so that six thousand foot portion is you know the CUNY boards kind of weighed in there.\n                                                                                                                                                                 1
# All of these calls and meetings, and just has really kind of been with the community board dating back to prior to 2018, when there was the Pacific street rezonings on 10:50 considered and then Pacific and grand.\n                                                                                                                                                                                                                                                                                                                                                         1
# These options all apply to the rezoning here to C62A and the C45D applied to the Atlantic avenue lots as a clarification not to the Pacific street lots which are already zoned R7A under the proposal that that's my motion                                                                                                                                                                                                                                                                                                                                                   1
# Thank you very much for that answer, but so, just if I can ask specifically about the Gowanus resulting I mean it's the largest rezoning so far of the De Blasio administration, and everyone just thinks it just includes Gowanus, not many people, except people like us or in the weeds, realize that it goes all the way to Pacific street and fourth avenue.\n                                                                                                                                                                                                            1
# Name: key_sentence, dtype: int64

# %% [markdown]
# # todo:
# - remove duplicate sentence, if sentence contains rezoning multiple times, we will capture it multiple times.

# %%
look_into = df[(df['key_sentence'].astype(str).str.contains('Atlantic')) & df['key_sentence'].astype(str).str.contains('crown')]['key_sentence'].value_counts()

# %%
# df[(df['key_sentence'].astype(str).str.contains('Seaport'))]['key_sentence'].value_counts()

# %%
top_locations = Counter(list(itertools.chain.from_iterable(df[df['LOC_list'].notna()]['LOC_list'].to_list())))

# %%
Counter.most_common(top_locations, 100)
# Out:
# [('Atlantic', 198),
#  ('Harlem', 109),
#  ('East Midtown', 88),
#  ('east Midtown', 68),
#  ('Gowanus', 67),
#  ('Pacific', 59),
#  ('East Harlem', 51),
#  ('Hudson', 49),
#  ('Long Island City', 48),
#  ('Europe', 45),
#  ('the Upper East Side', 39),
#  ('Inwood', 31),
#  ('R7D zoning district', 25),
#  ('Pacific street', 25),
#  ('the Upper West Side', 23),
#  ('Northern Boulevard', 23),
#  ('Crown Heights', 22),
#  ('West', 22),
#  ('NYC', 20),
#  ('West Chelsea', 19),
#  ('the east river', 19),
#  ('Midtown', 18),
#  ('South', 17),
#  ('Bay Ridge', 15),
#  ('Seaport', 15),
#  ('c43 zoning district', 15),
#  ('the Long Island City', 15),
#  ('East', 14),
#  ('Atlantic avenue', 14),
#  ('Red Hook', 14),
#  ('Upper West Side', 13),
#  ('the Upper East', 12),
#  ('Grand Central', 12),
#  ('M12', 12),
#  ('Staten Island', 11),
#  ('South Island', 10),
#  ('Flushing', 10),
#  ('van wyck expressway', 10),
#  ('the zoning district', 10),
#  ('North island', 9),
#  ('Midtown east', 9),
#  ('the Garment District', 9),
#  ('Park Slope', 9),
#  ('south island', 9),
#  ('West Chelsea District', 9),
#  ('Midtown East', 8),
#  ('the south island', 8),
#  ('the Bay Ridge', 8),
#  ('East Side', 8),
#  ('Prospect Heights', 8),
#  ('R6B district', 8),
#  ('R5 Ocean Parkway', 8),
#  ('the borum hill', 8),
#  ('Natural Area District', 8),
#  ('the Gowanus canal', 7),
#  ('North', 7),
#  ('Garment District', 7),
#  ('Lower East Side', 7),
#  ('M14D zoning district', 7),
#  ('Hudson boulevard', 7),
#  ('C45A district', 7),
#  ('South Richmond', 7),
#  ('Soho', 6),
#  ('East New York', 6),
#  ('Upper East Side', 6),
#  ('Sheepshead bay', 6),
#  ('Long Island', 6),
#  ('the East Midtown', 6),
#  ('Northeast', 6),
#  ('Hudson River Park', 6),
#  ('Terminus', 6),
#  ('the zoning district boundary', 5),
#  ('North Island', 5),
#  ('the South Island', 5),
#  ('Metro North', 5),
#  ('Soho Noho', 5),
#  ('the Lower East Side', 5),
#  ('the m12 district', 5),
#  ('Lower Manhattan', 5),
#  ('Community District', 5),
#  ('Qnr 6A', 4),
#  ('C12', 4),
#  ('Pacific park', 4),
#  ('the Bay Ridge Special District', 4),
#  ('West Side', 4),
#  ('M1', 4),
#  ('Central Park West', 4),
#  ('the rizzonian area', 4),
#  ('castleville avenue', 4),
#  ('D.O.T', 4),
#  ('the north island', 4),
#  ('Rockaway beach', 4),
#  ('Gowanus Soho', 4),
#  ('Midwood', 4),
#  ('c43', 4),
#  ('East Fordham', 4),
#  ('1160 Flushing', 4),
#  ('Midtown District', 4),
#  ('Google NYC', 4),
#  ('R5 District', 4)]
